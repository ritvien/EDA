# %% [markdown]
# ## PANDAS

# %%
import pandas as pd
import numpy as np

# %% [markdown]
# ## Creating a Series, DataFrame

# %%
s = pd.Series([1,3,5,np.nan,6,8])
s
# Out:
# 0    1.0
# 1    3.0
# 2    5.0
# 3    NaN
# 4    6.0
# 5    8.0
# dtype: float64

# %%
d = pd.DataFrame(np.random.randn(6, 4), columns=list("ABCD"))
d
# Out:
#           A         B         C         D
# 0  0.453736 -1.584603 -0.652742 -2.845640
# 1  0.098843 -1.076240  1.723864 -0.159672
# 2  0.199709  0.583947  1.211962 -1.812979
# 3 -0.668941 -1.159110  0.109770  1.249901
# 4  0.025355 -0.303316 -1.108764  0.297544
# 5  0.400884  0.051069  1.358437 -0.837778

# %%
df = pd.read_csv("chipotle.tsv",sep = "\t")

# %%
df
# Out:
#       order_id  quantity                              item_name  \
# 0            1         1           Chips and Fresh Tomato Salsa
# 1            1         1                                   Izze
# 2            1         1                       Nantucket Nectar
# 3            1         1  Chips and Tomatillo-Green Chili Salsa
# 4            2         2                           Chicken Bowl
# ...        ...       ...                                    ...
# 4617      1833         1                          Steak Burrito
# 4618      1833         1                          Steak Burrito
# 4619      1834         1                     Chicken Salad Bowl
# 4620      1834         1                     Chicken Salad Bowl
# 4621      1834         1                     Chicken Salad Bowl
#
#                                      choice_description item_price
# 0                                                   NaN     $2.39
# 1                                          [Clementine]     $3.39
# 2                                               [Apple]     $3.39
# 3                                                   NaN     $2.39
# 4     [Tomatillo-Red Chili Salsa (Hot), [Black Beans...    $16.98
# ...                                                 ...        ...
# 4617  [Fresh Tomato Salsa, [Rice, Black Beans, Sour ...    $11.75
# 4618  [Fresh Tomato Salsa, [Rice, Sour Cream, Cheese...    $11.75
# 4619  [Fresh Tomato Salsa, [Fajita Vegetables, Pinto...    $11.25
# 4620  [Fresh Tomato Salsa, [Fajita Vegetables, Lettu...     $8.75
# 4621  [Fresh Tomato Salsa, [Fajita Vegetables, Pinto...     $8.75
#
# [4622 rows x 5 columns]

# %%
df.head(4)
# Out:
#    order_id  quantity                              item_name  \
# 0         1         1           Chips and Fresh Tomato Salsa
# 1         1         1                                   Izze
# 2         1         1                       Nantucket Nectar
# 3         1         1  Chips and Tomatillo-Green Chili Salsa
#
#   choice_description item_price
# 0                NaN     $2.39
# 1       [Clementine]     $3.39
# 2            [Apple]     $3.39
# 3                NaN     $2.39

# %%
df.tail(4)
# Out:
#       order_id  quantity           item_name  \
# 4618      1833         1       Steak Burrito
# 4619      1834         1  Chicken Salad Bowl
# 4620      1834         1  Chicken Salad Bowl
# 4621      1834         1  Chicken Salad Bowl
#
#                                      choice_description item_price
# 4618  [Fresh Tomato Salsa, [Rice, Sour Cream, Cheese...    $11.75
# 4619  [Fresh Tomato Salsa, [Fajita Vegetables, Pinto...    $11.25
# 4620  [Fresh Tomato Salsa, [Fajita Vegetables, Lettu...     $8.75
# 4621  [Fresh Tomato Salsa, [Fajita Vegetables, Pinto...     $8.75

# %%
df.shape
# Out:
# (4622, 5)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4622 entries, 0 to 4621
# Data columns (total 5 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   order_id            4622 non-null   int64
#  1   quantity            4622 non-null   int64
#  2   item_name           4622 non-null   object
#  3   choice_description  3376 non-null   object
#  4   item_price          4622 non-null   object
# dtypes: int64(2), object(3)
# memory usage: 180.7+ KB

# %%
df.columns
# Out:
# Index(['order_id', 'quantity', 'item_name', 'choice_description',
#        'item_price'],
#       dtype='object')

# %%
df.index
# Out:
# RangeIndex(start=0, stop=4622, step=1)

# %%
df.describe(include = "all")
# Out:
#            order_id     quantity     item_name choice_description item_price
# count   4622.000000  4622.000000          4622               3376       4622
# unique          NaN          NaN            50               1043         78
# top             NaN          NaN  Chicken Bowl        [Diet Coke]     $8.75
# freq            NaN          NaN           726                134        730
# mean     927.254868     1.075725           NaN                NaN        NaN
# std      528.890796     0.410186           NaN                NaN        NaN
# min        1.000000     1.000000           NaN                NaN        NaN
# 25%      477.250000     1.000000           NaN                NaN        NaN
# 50%      926.000000     1.000000           NaN                NaN        NaN
# 75%     1393.000000     1.000000           NaN                NaN        NaN
# max     1834.000000    15.000000           NaN                NaN        NaN

# %%
#ACCESS ROW,COL
df.head()
# Out:
#    order_id  quantity                              item_name  \
# 0         1         1           Chips and Fresh Tomato Salsa
# 1         1         1                                   Izze
# 2         1         1                       Nantucket Nectar
# 3         1         1  Chips and Tomatillo-Green Chili Salsa
# 4         2         2                           Chicken Bowl
#
#                                   choice_description item_price
# 0                                                NaN     $2.39
# 1                                       [Clementine]     $3.39
# 2                                            [Apple]     $3.39
# 3                                                NaN     $2.39
# 4  [Tomatillo-Red Chili Salsa (Hot), [Black Beans...    $16.98

# %% [markdown]
# ## .loc[row_lable,column_lable]
# *truy cập dựa theo nhãn

# %%
df.loc[135,'item_name']
# Out:
# 'Chicken Salad Bowl'

# %% [markdown]
# ## điều kiện

# %%
df.loc[df.quantity >=2]
# Out:
#       order_id  quantity           item_name  \
# 4            2         2        Chicken Bowl
# 18           9         2         Canned Soda
# 51          23         2         Canned Soda
# 135         60         2  Chicken Salad Bowl
# 148         67         2       Steak Burrito
# ...        ...       ...                 ...
# 4491      1786         4   Canned Soft Drink
# 4499      1789         2   Canned Soft Drink
# 4560      1812         2   Canned Soft Drink
# 4561      1813         2  Chicken Salad Bowl
# 4582      1822         2       Bottled Water
#
#                                      choice_description item_price
# 4     [Tomatillo-Red Chili Salsa (Hot), [Black Beans...    $16.98
# 18                                             [Sprite]     $2.18
# 51                                       [Mountain Dew]     $2.18
# 135   [Tomatillo Green Chili Salsa, [Sour Cream, Che...    $22.50
# 148   [Tomatillo-Red Chili Salsa (Hot), [Rice, Chees...    $17.98
# ...                                                 ...        ...
# 4491                                           [Sprite]     $5.00
# 4499                                             [Coke]     $2.50
# 4560                                             [Coke]     $2.50
# 4561  [Fresh Tomato Salsa, [Fajita Vegetables, Pinto...    $17.50
# 4582                                                NaN     $3.00
#
# [267 rows x 5 columns]

# %%
df.loc[(df.quantity == 2) & (df.item_name == "Chicken Salad Bowl"), ['order_id', 'quantity', 'item_price']]
# Out:
#       order_id  quantity item_price
# 135         60         2    $22.50
# 213         94         2    $22.50
# 315        137         2    $17.50
# 591        243         2    $22.50
# 633        261         2    $22.50
# 816        337         2    $22.50
# 864        357         2    $22.50
# 1110       459         2    $22.50
# 1923       777         2    $22.50
# 2419       960         2    $22.50
# 3167      1265         2    $17.50
# 3507      1409         2    $22.50
# 4561      1813         2    $17.50

# %% [markdown]
# ## .iloc[row_index,column_index]
# *truy cập dựa theo index

# %%
df.iloc[:,2]
# Out:
# 0                Chips and Fresh Tomato Salsa
# 1                                        Izze
# 2                            Nantucket Nectar
# 3       Chips and Tomatillo-Green Chili Salsa
# 4                                Chicken Bowl
#                         ...
# 4617                            Steak Burrito
# 4618                            Steak Burrito
# 4619                       Chicken Salad Bowl
# 4620                       Chicken Salad Bowl
# 4621                       Chicken Salad Bowl
# Name: item_name, Length: 4622, dtype: object

# %%
df.iloc[[135]]
# Out:
#      order_id  quantity           item_name  \
# 135        60         2  Chicken Salad Bowl
#
#                                     choice_description item_price
# 135  [Tomatillo Green Chili Salsa, [Sour Cream, Che...    $22.50

# %%
df.iloc[3:11]
# Out:
#     order_id  quantity                              item_name  \
# 3          1         1  Chips and Tomatillo-Green Chili Salsa
# 4          2         2                           Chicken Bowl
# 5          3         1                           Chicken Bowl
# 6          3         1                          Side of Chips
# 7          4         1                          Steak Burrito
# 8          4         1                       Steak Soft Tacos
# 9          5         1                          Steak Burrito
# 10         5         1                    Chips and Guacamole
#
#                                    choice_description item_price
# 3                                                 NaN     $2.39
# 4   [Tomatillo-Red Chili Salsa (Hot), [Black Beans...    $16.98
# 5   [Fresh Tomato Salsa (Mild), [Rice, Cheese, Sou...    $10.98
# 6                                                 NaN     $1.69
# 7   [Tomatillo Red Chili Salsa, [Fajita Vegetables...    $11.75
# 8   [Tomatillo Green Chili Salsa, [Pinto Beans, Ch...     $9.25
# 9   [Fresh Tomato Salsa, [Rice, Black Beans, Pinto...     $9.25
# 10                                                NaN     $4.45

# %%
X = df.iloc[3:5, :-1]

# %% [markdown]
# ## một số hàm
# #### .isin(['Steak Burrito','Side of Chips'])
# #### .isnull() : xem có phải là NaN không >< .notnull()
# #### .median() : trung vị
# #### .mean() : giá trị trung bình
# #### .idxmax() : trả về index có giá trị lớn nhất
# ### .agg([mean,max,min,....]) : thực hiện đồng thời nhiều phép tổng hợp khác nhau

# %% [markdown]
# ## apply()
# thêm, sửa, xóa

# %%
#Data Manipulation
df.item_price.dtype
# O : python(object)
# Out:
# dtype('O')

# %% [markdown]
# SỬA

# %%
df.item_price.apply(lambda x : float(x.replace('$',''))).dtype
# Out:
# dtype('float64')

# %%
df.item_price = df.item_price.apply(lambda x : float(x.replace('$','')))

# %%
df
# Out:
#       order_id  quantity                              item_name  \
# 0            1         1           Chips and Fresh Tomato Salsa
# 1            1         1                                   Izze
# 2            1         1                       Nantucket Nectar
# 3            1         1  Chips and Tomatillo-Green Chili Salsa
# 4            2         2                           Chicken Bowl
# ...        ...       ...                                    ...
# 4617      1833         1                          Steak Burrito
# 4618      1833         1                          Steak Burrito
# 4619      1834         1                     Chicken Salad Bowl
# 4620      1834         1                     Chicken Salad Bowl
# 4621      1834         1                     Chicken Salad Bowl
#
#                                      choice_description  item_price
# 0                                                   NaN        2.39
# 1                                          [Clementine]        3.39
# 2                                               [Apple]        3.39
# 3                                                   NaN        2.39
# 4     [Tomatillo-Red Chili Salsa (Hot), [Black Beans...       16.98
# ...                                                 ...         ...
# 4617  [Fresh Tomato Salsa, [Rice, Black Beans, Sour ...       11.75
# 4618  [Fresh Tomato Salsa, [Rice, Sour Cream, Cheese...       11.75
# 4619  [Fresh Tomato Salsa, [Fajita Vegetables, Pinto...       11.25
# 4620  [Fresh Tomato Salsa, [Fajita Vegetables, Lettu...        8.75
# 4621  [Fresh Tomato Salsa, [Fajita Vegetables, Pinto...        8.75
#
# [4622 rows x 5 columns]

# %% [markdown]
# THÊM

# %%
df["total_price"] = df["quantity"]*df["item_price"]
df.head()
# Out:
#    order_id  quantity                              item_name  \
# 0         1         1           Chips and Fresh Tomato Salsa
# 1         1         1                                   Izze
# 2         1         1                       Nantucket Nectar
# 3         1         1  Chips and Tomatillo-Green Chili Salsa
# 4         2         2                           Chicken Bowl
#
#                                   choice_description  item_price  total_price
# 0                                                NaN        2.39         2.39
# 1                                       [Clementine]        3.39         3.39
# 2                                            [Apple]        3.39         3.39
# 3                                                NaN        2.39         2.39
# 4  [Tomatillo-Red Chili Salsa (Hot), [Black Beans...       16.98        33.96

# %%
df.Total_price = df.quantity * df.item_price
# Out:
# C:\Users\Dell\AppData\Local\Temp\ipykernel_10668\3380708017.py:1: UserWarning: Pandas doesn't allow columns to be created via a new attribute name - see https://pandas.pydata.org/pandas-docs/stable/indexing.html#attribute-access
#   df.Total_price = df.quantity * df.item_price

# %%
df.quantity.dtype
# Out:
# dtype('int64')

# %%
df["quantity"].dtype
# Out:
# dtype('int64')

# %%
df
# Out:
#       order_id  quantity                              item_name  \
# 0            1         1           Chips and Fresh Tomato Salsa
# 1            1         1                                   Izze
# 2            1         1                       Nantucket Nectar
# 3            1         1  Chips and Tomatillo-Green Chili Salsa
# 4            2         2                           Chicken Bowl
# ...        ...       ...                                    ...
# 4617      1833         1                          Steak Burrito
# 4618      1833         1                          Steak Burrito
# 4619      1834         1                     Chicken Salad Bowl
# 4620      1834         1                     Chicken Salad Bowl
# 4621      1834         1                     Chicken Salad Bowl
#
#                                      choice_description  item_price  \
# 0                                                   NaN        2.39
# 1                                          [Clementine]        3.39
# 2                                               [Apple]        3.39
# 3                                                   NaN        2.39
# 4     [Tomatillo-Red Chili Salsa (Hot), [Black Beans...       16.98
# ...                                                 ...         ...
# 4617  [Fresh Tomato Salsa, [Rice, Black Beans, Sour ...       11.75
# 4618  [Fresh Tomato Salsa, [Rice, Sour Cream, Cheese...       11.75
# 4619  [Fresh Tomato Salsa, [Fajita Vegetables, Pinto...       11.25
# 4620  [Fresh Tomato Salsa, [Fajita Vegetables, Lettu...        8.75
# 4621  [Fresh Tomato Salsa, [Fajita Vegetables, Pinto...        8.75
#
#       total_price
# 0            2.39
# 1            3.39
# 2            3.39
# 3            2.39
# 4           33.96
# ...           ...
# 4617        11.75
# 4618        11.75
# 4619        11.25
# 4620         8.75
# 4621         8.75
#
# [4622 rows x 6 columns]

# %%
revenue= df["total_price"].sum()
print(revenue)
# Out:
# 39237.02

# %% [markdown]
# ## Group

# %%
c = df.groupby("item_name")["quantity"].sum()
c
# Out:
# item_name
# 6 Pack Soft Drink                         55
# Barbacoa Bowl                             66
# Barbacoa Burrito                          91
# Barbacoa Crispy Tacos                     12
# Barbacoa Salad Bowl                       10
# Barbacoa Soft Tacos                       25
# Bottled Water                            211
# Bowl                                       4
# Burrito                                    6
# Canned Soda                              126
# Canned Soft Drink                        351
# Carnitas Bowl                             71
# Carnitas Burrito                          60
# Carnitas Crispy Tacos                      8
# Carnitas Salad                             1
# Carnitas Salad Bowl                        6
# Carnitas Soft Tacos                       40
# Chicken Bowl                             761
# Chicken Burrito                          591
# Chicken Crispy Tacos                      50
# Chicken Salad                              9
# Chicken Salad Bowl                       123
# Chicken Soft Tacos                       120
# Chips                                    230
# Chips and Fresh Tomato Salsa             130
# Chips and Guacamole                      506
# Chips and Mild Fresh Tomato Salsa          1
# Chips and Roasted Chili Corn Salsa        23
# Chips and Roasted Chili-Corn Salsa        18
# Chips and Tomatillo Green Chili Salsa     45
# Chips and Tomatillo Red Chili Salsa       50
# Chips and Tomatillo-Green Chili Salsa     33
# Chips and Tomatillo-Red Chili Salsa       25
# Crispy Tacos                               2
# Izze                                      20
# Nantucket Nectar                          29
# Salad                                      2
# Side of Chips                            110
# Steak Bowl                               221
# Steak Burrito                            386
# Steak Crispy Tacos                        36
# Steak Salad                                4
# Steak Salad Bowl                          31
# Steak Soft Tacos                          56
# Veggie Bowl                               87
# Veggie Burrito                            97
# Veggie Crispy Tacos                        1
# Veggie Salad                               6
# Veggie Salad Bowl                         18
# Veggie Soft Tacos                          8
# Name: quantity, dtype: int64

# %% [markdown]
# ## SẮP XẾP
# ### .sort_values(by = 'cột muốn sx', ascending = True(tăng dần),axis=0(theo hàng)=1(theo cột)

# %%
c.sort_values()
# Out:
# item_name
# Carnitas Salad                             1
# Veggie Crispy Tacos                        1
# Chips and Mild Fresh Tomato Salsa          1
# Crispy Tacos                               2
# Salad                                      2
# Bowl                                       4
# Steak Salad                                4
# Veggie Salad                               6
# Carnitas Salad Bowl                        6
# Burrito                                    6
# Carnitas Crispy Tacos                      8
# Veggie Soft Tacos                          8
# Chicken Salad                              9
# Barbacoa Salad Bowl                       10
# Barbacoa Crispy Tacos                     12
# Veggie Salad Bowl                         18
# Chips and Roasted Chili-Corn Salsa        18
# Izze                                      20
# Chips and Roasted Chili Corn Salsa        23
# Barbacoa Soft Tacos                       25
# Chips and Tomatillo-Red Chili Salsa       25
# Nantucket Nectar                          29
# Steak Salad Bowl                          31
# Chips and Tomatillo-Green Chili Salsa     33
# Steak Crispy Tacos                        36
# Carnitas Soft Tacos                       40
# Chips and Tomatillo Green Chili Salsa     45
# Chicken Crispy Tacos                      50
# Chips and Tomatillo Red Chili Salsa       50
# 6 Pack Soft Drink                         55
# Steak Soft Tacos                          56
# Carnitas Burrito                          60
# Barbacoa Bowl                             66
# Carnitas Bowl                             71
# Veggie Bowl                               87
# Barbacoa Burrito                          91
# Veggie Burrito                            97
# Side of Chips                            110
# Chicken Soft Tacos                       120
# Chicken Salad Bowl                       123
# Canned Soda                              126
# Chips and Fresh Tomato Salsa             130
# Bottled Water                            211
# Steak Bowl                               221
# Chips                                    230
# Canned Soft Drink                        351
# Steak Burrito                            386
# Chips and Guacamole                      506
# Chicken Burrito                          591
# Chicken Bowl                             761
# Name: quantity, dtype: int64

# %%
c.sort_values(ascending = False).head()
# Out:
# item_name
# Chicken Bowl           761
# Chicken Burrito        591
# Chips and Guacamole    506
# Steak Burrito          386
# Canned Soft Drink      351
# Name: quantity, dtype: int64

# %% [markdown]
# ## Unique value

# %% [markdown]
# ### .values_counts() : thống kê, xem số lần xuất hiện của từng giá trị duy nhất
# ### .unique()  : xuất ra các giá trị xuất hiện duy nhất (tên)
# ### .nunique() : xuất ra số giá trị xuất hiện duy nhất (số)

# %%
df.item_name.value_counts()
# Out:
# Chicken Bowl                             726
# Chicken Burrito                          553
# Chips and Guacamole                      479
# Steak Burrito                            368
# Canned Soft Drink                        301
# Steak Bowl                               211
# Chips                                    211
# Bottled Water                            162
# Chicken Soft Tacos                       115
# Chips and Fresh Tomato Salsa             110
# Chicken Salad Bowl                       110
# Canned Soda                              104
# Side of Chips                            101
# Veggie Burrito                            95
# Barbacoa Burrito                          91
# Veggie Bowl                               85
# Carnitas Bowl                             68
# Barbacoa Bowl                             66
# Carnitas Burrito                          59
# Steak Soft Tacos                          55
# 6 Pack Soft Drink                         54
# Chips and Tomatillo Red Chili Salsa       48
# Chicken Crispy Tacos                      47
# Chips and Tomatillo Green Chili Salsa     43
# Carnitas Soft Tacos                       40
# Steak Crispy Tacos                        35
# Chips and Tomatillo-Green Chili Salsa     31
# Steak Salad Bowl                          29
# Nantucket Nectar                          27
# Barbacoa Soft Tacos                       25
# Chips and Roasted Chili Corn Salsa        22
# Izze                                      20
# Chips and Tomatillo-Red Chili Salsa       20
# Veggie Salad Bowl                         18
# Chips and Roasted Chili-Corn Salsa        18
# Barbacoa Crispy Tacos                     11
# Barbacoa Salad Bowl                       10
# Chicken Salad                              9
# Veggie Soft Tacos                          7
# Carnitas Crispy Tacos                      7
# Veggie Salad                               6
# Carnitas Salad Bowl                        6
# Burrito                                    6
# Steak Salad                                4
# Crispy Tacos                               2
# Salad                                      2
# Bowl                                       2
# Chips and Mild Fresh Tomato Salsa          1
# Veggie Crispy Tacos                        1
# Carnitas Salad                             1
# Name: item_name, dtype: int64

# %%
df.item_name.value_counts().count()
# Out:
# 50

# %%
df.item_name.nunique()
# Out:
# 50

# %%
df.loc[:]
# Out:
#       order_id  quantity                              item_name  \
# 0            1         1           Chips and Fresh Tomato Salsa
# 1            1         1                                   Izze
# 2            1         1                       Nantucket Nectar
# 3            1         1  Chips and Tomatillo-Green Chili Salsa
# 4            2         2                           Chicken Bowl
# ...        ...       ...                                    ...
# 4617      1833         1                          Steak Burrito
# 4618      1833         1                          Steak Burrito
# 4619      1834         1                     Chicken Salad Bowl
# 4620      1834         1                     Chicken Salad Bowl
# 4621      1834         1                     Chicken Salad Bowl
#
#                                      choice_description item_price
# 0                                                   NaN     $2.39
# 1                                          [Clementine]     $3.39
# 2                                               [Apple]     $3.39
# 3                                                   NaN     $2.39
# 4     [Tomatillo-Red Chili Salsa (Hot), [Black Beans...    $16.98
# ...                                                 ...        ...
# 4617  [Fresh Tomato Salsa, [Rice, Black Beans, Sour ...    $11.75
# 4618  [Fresh Tomato Salsa, [Rice, Sour Cream, Cheese...    $11.75
# 4619  [Fresh Tomato Salsa, [Fajita Vegetables, Pinto...    $11.25
# 4620  [Fresh Tomato Salsa, [Fajita Vegetables, Lettu...     $8.75
# 4621  [Fresh Tomato Salsa, [Fajita Vegetables, Pinto...     $8.75
#
# [4622 rows x 5 columns]

# %%
df.iloc[:]
# Out:
#       order_id  quantity                              item_name  \
# 0            1         1           Chips and Fresh Tomato Salsa
# 1            1         1                                   Izze
# 2            1         1                       Nantucket Nectar
# 3            1         1  Chips and Tomatillo-Green Chili Salsa
# 4            2         2                           Chicken Bowl
# ...        ...       ...                                    ...
# 4617      1833         1                          Steak Burrito
# 4618      1833         1                          Steak Burrito
# 4619      1834         1                     Chicken Salad Bowl
# 4620      1834         1                     Chicken Salad Bowl
# 4621      1834         1                     Chicken Salad Bowl
#
#                                      choice_description item_price
# 0                                                   NaN     $2.39
# 1                                          [Clementine]     $3.39
# 2                                               [Apple]     $3.39
# 3                                                   NaN     $2.39
# 4     [Tomatillo-Red Chili Salsa (Hot), [Black Beans...    $16.98
# ...                                                 ...        ...
# 4617  [Fresh Tomato Salsa, [Rice, Black Beans, Sour ...    $11.75
# 4618  [Fresh Tomato Salsa, [Rice, Sour Cream, Cheese...    $11.75
# 4619  [Fresh Tomato Salsa, [Fajita Vegetables, Pinto...    $11.25
# 4620  [Fresh Tomato Salsa, [Fajita Vegetables, Lettu...     $8.75
# 4621  [Fresh Tomato Salsa, [Fajita Vegetables, Pinto...     $8.75
#
# [4622 rows x 5 columns]

# %% [markdown]
# # Map(funtion,iterable)
# #### : x1 --> f(x1)
# #### : x2 --> f(x2)
# ### ......

# %%
df.item_name.map(lambda x : "Chicken" in x).sum()
#sum() : tổng các giá trị trong 1 series
# Out:
# 1560

# %% [markdown]
# ## có thể dùng vòng for để chạy như map
# #### for i in range(0,len(reviews.columns)):
# ####    reviews.loc[i,'star_ratings'] = 3 if ((reviews.iloc[i,3]>= 95) | (reviews.loc[i,'country']=='Canada')) else (2 if reviews.loc[i,'points']>=85 else 1)
# #### print(star_ratings)

# %% [markdown]
# # Group

# %% [markdown]
# #### df.groupby(cột).cột_nào_đó(điều kiện).hàm_nào_đó(sum,count) : trả về một Series

# %% [markdown]
# ## Data Types and Missing values

# %% [markdown]
# #### df.quantity.astype('str') : chuyển từ kiểu cũ sang string

# %% [markdown]
# #### df.quantity.isnull().sum() : đếm số phần tử NaN

# %% [markdown]
# #### df.choice_description.fillna("Text") : lấp đầy NaN = Text

# %% [markdown]
# # Rename and combine

# %%
df.rename(columns={'quantity':'amount','item_price':'price'}) #: đổi tên từng cột hoặc chỉ mục trong dataframe hoặc series
# Out:
#       order_id  amount                              item_name  \
# 0            1       1           Chips and Fresh Tomato Salsa
# 1            1       1                                   Izze
# 2            1       1                       Nantucket Nectar
# 3            1       1  Chips and Tomatillo-Green Chili Salsa
# 4            2       2                           Chicken Bowl
# ...        ...     ...                                    ...
# 4617      1833       1                          Steak Burrito
# 4618      1833       1                          Steak Burrito
# 4619      1834       1                     Chicken Salad Bowl
# 4620      1834       1                     Chicken Salad Bowl
# 4621      1834       1                     Chicken Salad Bowl
#
#                                      choice_description    price
# 0                                                   NaN   $2.39
# 1                                          [Clementine]   $3.39
# 2                                               [Apple]   $3.39
# 3                                                   NaN   $2.39
# 4     [Tomatillo-Red Chili Salsa (Hot), [Black Beans...  $16.98
# ...                                                 ...      ...
# 4617  [Fresh Tomato Salsa, [Rice, Black Beans, Sour ...  $11.75
# 4618  [Fresh Tomato Salsa, [Rice, Sour Cream, Cheese...  $11.75
# 4619  [Fresh Tomato Salsa, [Fajita Vegetables, Pinto...  $11.25
# 4620  [Fresh Tomato Salsa, [Fajita Vegetables, Lettu...   $8.75
# 4621  [Fresh Tomato Salsa, [Fajita Vegetables, Pinto...   $8.75
#
# [4622 rows x 5 columns]

# %%
df.rename_axis(index = 'NewIndex',columns = 'NewColumns') #: đổi tên các chỉ mục hoặc cột trong dataframe
# Out:
# NewColumns  order_id  quantity                              item_name  \
# NewIndex
# 0                  1         1           Chips and Fresh Tomato Salsa
# 1                  1         1                                   Izze
# 2                  1         1                       Nantucket Nectar
# 3                  1         1  Chips and Tomatillo-Green Chili Salsa
# 4                  2         2                           Chicken Bowl
# ...              ...       ...                                    ...
# 4617            1833         1                          Steak Burrito
# 4618            1833         1                          Steak Burrito
# 4619            1834         1                     Chicken Salad Bowl
# 4620            1834         1                     Chicken Salad Bowl
# 4621            1834         1                     Chicken Salad Bowl
#
# NewColumns                                 choice_description item_price
# NewIndex
# 0                                                         NaN     $2.39
# 1                                                [Clementine]     $3.39
# 2                                                     [Apple]     $3.39
# 3                                                         NaN     $2.39
# 4           [Tomatillo-Red Chili Salsa (Hot), [Black Beans...    $16.98
# ...                                                       ...        ...
# 4617        [Fresh Tomato Salsa, [Rice, Black Beans, Sour ...    $11.75
# 4618        [Fresh Tomato Salsa, [Rice, Sour Cream, Cheese...    $11.75
# 4619        [Fresh Tomato Salsa, [Fajita Vegetables, Pinto...    $11.25
# 4620        [Fresh Tomato Salsa, [Fajita Vegetables, Lettu...     $8.75
# 4621        [Fresh Tomato Salsa, [Fajita Vegetables, Pinto...     $8.75
#
# [4622 rows x 5 columns]

# %% [markdown]
# ## Combine (có thể nối giữa cả DF và Series)
# ### combined_df = pd.concat([df1,df2]) nối 2 bảng với nhau theo cột (thêm hàng, k thêm cột)
# #####      tham số ,ignore_index = True : cập nhật cột index
# #####      tham số ,keys = ["Df1","Df2"] : thêm tên của mỗi df cũ trước khi concatenate
# #####      tham số ,axis=1 : nối theo hàng(thêm cột, k thêm hàng, default = 0) *** cột nào giống nhau thì nối theo cột
# ### new_df = df.set_index(['cột1','cột2']) : đặt cột làm chỉ mục

# %% [markdown]
# ## Join()
# ### df1.join(df2, on = 'c', how='left' 'right' 'outer' 'inner' ) ***df1 và df2 là 2 cột muốn kết hợp, c là cột chung giữa các df, outer: giữ tất cả các hàng từ 2 df, inner: chỉ giữ lại hàng có giá trị khớp
